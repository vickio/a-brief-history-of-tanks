# %%
# using 1.0 because 1.1 started giving me a sep_token error that I couldn't figure out
# !pip install pytorch_transformers==1.0

# %%
from google.colab import drive
import os, nltk
from GPT2 import GPT2

drive.mount('/content/drive')
os.chdir('/content/drive/My Drive/Colab Notebooks')

# download and initialize GPT-2 medium pretrained model
gpt2_module = GPT2()

nltk.download('punkt')

# %%
from challenge_entry import ChallengeEntry

ChallengeEntry.make_some_tanks(
    count=350,
    output_file='A Brief History of Tanks.md',
    preview=False
)
